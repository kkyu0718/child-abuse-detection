# %%
import sqlalchemy
from sqlalchemy import create_engine, Table, Column, Integer, String, ForeignKey, MetaData, DateTime, Float
from sqlalchemy.orm.session import Session, sessionmaker, query
from sqlalchemy.ext.declarative import declarative_base
base = declarative_base()

# %%
engine = create_engine('sqlite:///child_abuse_detection_database.db',echo=True)

# %%
class Location(base):
    __tablename__ = 'location'
    id = Column(Integer, primary_key=True)
    name = Column(Integer, nullable=False)

# %%
class User(base):
    __tablename__ = 'user'
    id = Column(Integer, primary_key=True)
    email = Column(String, nullable=False)
    pw = Column(String, nullable=False)
    office_num = Column(Integer, nullable=False)
    department = Column(String, nullable=False)
    name = Column(String, nullable=False)
    ph_num1 = Column(String, nullable=False)
    ph_num2 = Column(String, nullable=False)
    ph_num3 = Column(String, nullable=False)
    loc_id = Column(ForeignKey(Location.id))

# %%
class DaycareCenter(base):
    __tablename__ = 'daycare_center'
    
    id = Column(Integer, primary_key=True)
    name = Column(Integer, nullable=False)
    chief_staff_name = Column(String, nullable=False)
    address = Column(String, nullable=False)
    ph_num1 = Column(String, nullable=False)
    ph_num2 = Column(String, nullable=False)
    ph_num3 = Column(String, nullable=False)
    loc_id = Column(ForeignKey(Location.id))

# %%
class Video(base):
    __tablename__ = 'video'
    
    id = Column(Integer, primary_key=True)
    detection_time = Column(Integer, nullable=False)
    name = Column(String, nullable=False)
    accuracy = Column(Float, nullable=False)
    status = Column(String, nullable=False)
    loc_id = Column(ForeignKey(Location.id))
    dc_id = Column(ForeignKey(DaycareCenter.id))

# %%
class ReportList(base):
    __tablename__ = 'report_list'
    
    id = Column(Integer, primary_key=True)
    time = Column(Integer, nullable=False) 
    police_name = Column(String, nullable=False) 
    status = Column(String, nullable=False) 

    loc_id = Column(ForeignKey(Location.id))
    dc_id = Column(ForeignKey(DaycareCenter.id))
    vid_id = Column(ForeignKey(Video.id))

# %%
base.metadata.create_all(engine)
# Out:
# 2021-08-18 17:40:38,853 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-08-18 17:40:38,856 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,858 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-08-18 17:40:38,859 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,860 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("location")
# 2021-08-18 17:40:38,861 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,864 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("location")
# 2021-08-18 17:40:38,864 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,866 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("user")
# 2021-08-18 17:40:38,866 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,868 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("user")
# 2021-08-18 17:40:38,869 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,869 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("daycare_center")
# 2021-08-18 17:40:38,870 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,871 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("daycare_center")
# 2021-08-18 17:40:38,873 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,874 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("video")
# 2021-08-18 17:40:38,875 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,876 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("video")
# 2021-08-18 17:40:38,877 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,878 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("report_list")
# 2021-08-18 17:40:38,878 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,880 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("report_list")
# 2021-08-18 17:40:38,881 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,883 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE location (
# 	id INTEGER NOT NULL,
# 	name INTEGER NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-08-18 17:40:38,883 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,903 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-18 17:40:38,905 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE user (
# 	id INTEGER NOT NULL,
# 	email VARCHAR NOT NULL,
# 	pw VARCHAR NOT NULL,
# 	office_num INTEGER NOT NULL,
# 	department VARCHAR NOT NULL,
# 	name VARCHAR NOT NULL,
# 	ph_num1 VARCHAR NOT NULL,
# 	ph_num2 VARCHAR NOT NULL,
# 	ph_num3 VARCHAR NOT NULL,
# 	loc_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(loc_id) REFERENCES location (id)
# )
#
#
# 2021-08-18 17:40:38,905 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,924 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-18 17:40:38,926 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE daycare_center (
# 	id INTEGER NOT NULL,
# 	name INTEGER NOT NULL,
# 	chief_staff_name VARCHAR NOT NULL,
# 	address VARCHAR NOT NULL,
# 	ph_num1 VARCHAR NOT NULL,
# 	ph_num2 VARCHAR NOT NULL,
# 	ph_num3 VARCHAR NOT NULL,
# 	loc_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(loc_id) REFERENCES location (id)
# )
#
#
# 2021-08-18 17:40:38,927 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,944 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-18 17:40:38,945 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE video (
# 	id INTEGER NOT NULL,
# 	detection_time INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	accuracy FLOAT NOT NULL,
# 	status VARCHAR NOT NULL,
# 	loc_id INTEGER,
# 	dc_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(loc_id) REFERENCES location (id),
# 	FOREIGN KEY(dc_id) REFERENCES daycare_center (id)
# )
#
#
# 2021-08-18 17:40:38,947 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,968 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-18 17:40:38,969 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE report_list (
# 	id INTEGER NOT NULL,
# 	time INTEGER NOT NULL,
# 	police_name VARCHAR NOT NULL,
# 	status VARCHAR NOT NULL,
# 	loc_id INTEGER,
# 	dc_id INTEGER,
# 	vid_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(loc_id) REFERENCES location (id),
# 	FOREIGN KEY(dc_id) REFERENCES daycare_center (id),
# 	FOREIGN KEY(vid_id) REFERENCES video (id)
# )
#
#
# 2021-08-18 17:40:38,972 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-18 17:40:38,989 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# # Creating Dummy Data

# %%
import numpy as np
import datetime
import time
import string
import re

# %%
sess = sessionmaker()
session = sess(bind=engine)

# %%
def create_random_phone_num():
    num1 = 10
    num2 = np.random.randint(0,10000)
    num3 = np.random.randint(0,10000)
    return num1, num2, num3

# %%
def create_random_name():
    lastname = list('김이박최정강조윤장임한오서신권황안송류전')
    firstname = ['정웅','영철','영식','영철','성진','정운','준혁','준서',
                 '영길','정수','성수','정호','지훈','동현','준호','민재',
                 '영일','종수','성호','영진','상훈','성호','준영','민석',
                 '도현','건우','예준','정수','정식','상철','병철','성민',
                 '민수','지훈','예준','건우','정남','정호','종수','진호',
                 '영진','준호','준호','준혁','준영','현준','광수','영환',
                 '영자','순자','미경','미영','지영','지혜','유진','서연',
                 '정자','미숙','은정','지은','민지','민서','정순','경회',
                 '수빈','서현','영숙','경숙','은영','현정','혜진','지원',
                 '경자','은경','은영','지영','지은','민지','예은','지민']
    last = np.random.choice(lastname, 1)
    first = np.random.choice(firstname,1)
    return last[0] + first[0]

# %%
def create_random_time():
    return np.random.randint(0,164000000,10) * 10

# %%
def create_random_email():
    alpha = list(string.ascii_lowercase)
    number = list('0123456789')
    domain = ['gmail.com','naver.com','google.com','daum.net','aspo.dor','foke.ok','github.io','please.work','korea.ac.kr','kakao.com']
    n = np.random.randint(1,7)
    k = 10-n
    return ''.join(np.random.choice(alpha,n)) + ''.join(np.random.choice(number,k)) + '@'+''.join(np.random.choice(domain,1))

# %%
def create_random_password():
    alpha = list(string.ascii_lowercase)
    number = list('0123456789')
    data = alpha + number
    return ''.join(np.random.choice(data,10))

# %%
def create_random_office_num():
    number = list('123456789')
    return ''.join(np.random.choice(number,8))

# %%
def create_random_department():
    dep = '''균형발전본부, 균형발전기획관, 균형발전정책과, 도시활성화과, 주거재생과, 주거환경과, 도심권사업과, 한옥정책과, 안전총괄실, 안전총괄관, 안전총괄과, 상황대응과, 시설안전과, 도로계획과, 광화문광장추진단, 감염병연구센터, 여성가족정책실, 여성권익담당관, 여성정책담당관, 보육담당관, 외국인다문화담당관, 가족담당관, 아이돌봄담당관, 온마을돌봄추진단, 공공개발기획단, 동물보호과, 미래청년기획단, 청년정책반, 청년사업반, 국제교류담당관, 인생이모작담당관, 행정국, 총무과, 인사과, 자치행정과, 인력개발과, 정보공개정책과, 법률자문검사, 국회협력관, 시장단, 코로나19대응지원과, 1인가구특별대책추진단, 기획조정실, 정책기획관, 기획담당관, 조직담당관, 평가협업담당관, 법무담당관, 대외협력담당관, 재정기획관, 예산담당관, 재정담당관, 공기업담당관, 법률지원담당관, 식품정책과, 복지정책실, 복지기획관, 복지정책과, 지역돌봄복지과, 어르신복지과, 자활지원과, 시민건강국, 보건의료정책과, 건강증진과, 감염병관리과, 비상기획관, 민방위담당관, 도로관리과, 도로시설과, 건설혁신과, 동남권사업과, 동북권사업과, 서부권사업과, 교량안전과, 대변인, 언론담당관, 인권담당관, 시민소통기획관, 시민소통담당관, 시민봉사담당관, 뉴미디어담당관, 도시브랜드담당관, 장애인자립지원과, 장애인복지정책과, 시민봉사담당관(열린민원실)'''
    department = re.sub(' ','',dep).split(',')
    return np.random.choice(department,1)[0]

# %%
def convert_datetime(unixtime):
    """Convert unixtime to datetime"""
    date = datetime.datetime.fromtimestamp(unixtime).strftime('%Y-%m-%d %H:%M:%S')
    return date # format : str

def convert_unixtime(date_time):
    """Convert datetime to unixtime"""
    unixtime = datetime.datetime.strptime(date_time,'%Y-%m-%d %H:%M:%S').timestamp()
    return unixtime

# %%
for i in range(10,24):
    p_num1,p_num2, p_num3 = create_random_phone_num()
    user_1 = User(email=create_random_email(), 
                  pw=create_random_password(), 
                  office_num=create_random_office_num(),
                  department=create_random_department(),
                  name=create_random_name(),
                  ph_num1=p_num1,
                  ph_num2=p_num2,
                  ph_num3=p_num3, 
                  loc_id=i+2)
    session.add(user_1)

# %%
session.commit()
# Out:
# 2021-08-18 18:34:19,853 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-18 18:34:19,856 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,857 INFO sqlalchemy.engine.base.Engine ('ltp7162483@korea.ac.kr', 'x7w63fszs2', '85667212', '시민봉사담당관(열린민원실)', '한은정', 10, 179, 653, 12)
# 2021-08-18 18:34:19,861 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,862 INFO sqlalchemy.engine.base.Engine ('ywhrw32383@naver.com', '219ple5zlw', '24476128', '공기업담당관', '서영숙', 10, 1255, 137, 13)
# 2021-08-18 18:34:19,863 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,864 INFO sqlalchemy.engine.base.Engine ('hmgpsa5623@github.io', 'e6ipo143f6', '97515527', '도로관리과', '박준영', 10, 5661, 8152, 14)
# 2021-08-18 18:34:19,865 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,866 INFO sqlalchemy.engine.base.Engine ('qvuaw15948@please.work', 'bow4fx5iks', '93353842', '도로관리과', '박혜진', 10, 7746, 7589, 15)
# 2021-08-18 18:34:19,867 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,867 INFO sqlalchemy.engine.base.Engine ('h123415666@daum.net', 'or23l2ban7', '98259858', '예산담당관', '류성호', 10, 311, 4181, 16)
# 2021-08-18 18:34:19,868 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,869 INFO sqlalchemy.engine.base.Engine ('iyzt822642@aspo.dor', '2rhoinszfb', '37186497', '대외협력담당관', '윤준호', 10, 7113, 3824, 17)
# 2021-08-18 18:34:19,870 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,871 INFO sqlalchemy.engine.base.Engine ('aox5142093@google.com', 'oaghbo7az2', '43384749', '대변인', '전현준', 10, 5836, 2753, 18)
# 2021-08-18 18:34:19,872 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,873 INFO sqlalchemy.engine.base.Engine ('s166813538@google.com', 'k28hzho4oi', '81719572', '코로나19대응지원과', '서미숙', 10, 4011, 2597, 19)
# 2021-08-18 18:34:19,874 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,875 INFO sqlalchemy.engine.base.Engine ('uyn1705398@please.work', '3n99zew7bx', '18148459', '도시활성화과', '장지훈', 10, 7544, 1515, 20)
# 2021-08-18 18:34:19,876 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,876 INFO sqlalchemy.engine.base.Engine ('ridz830812@foke.ok', 'ww4fjbil87', '97353281', '동북권사업과', '임유진', 10, 1621, 801, 21)
# 2021-08-18 18:34:19,877 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,878 INFO sqlalchemy.engine.base.Engine ('jh61841047@google.com', 'fv94yngnev', '79933464', '법률자문검사', '장영식', 10, 5733, 1331, 22)
# 2021-08-18 18:34:19,881 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,882 INFO sqlalchemy.engine.base.Engine ('umho931468@foke.ok', 'zfxxfdwnoh', '72476987', '여성가족정책실', '신준서', 10, 610, 755, 23)
# 2021-08-18 18:34:19,883 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,884 INFO sqlalchemy.engine.base.Engine ('srn7166798@daum.net', 'nqw62bvtq0', '46811237', '균형발전정책과', '송준호', 10, 6412, 8381, 24)
# 2021-08-18 18:34:19,886 INFO sqlalchemy.engine.base.Engine INSERT INTO user (email, pw, office_num, department, name, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 18:34:19,887 INFO sqlalchemy.engine.base.Engine ('i263735542@aspo.dor', '84njveoy0c', '23573891', '1인가구특별대책추진단', '정준호', 10, 2385, 7328, 25)
# 2021-08-18 18:34:19,889 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
location_list = '''강남구,강동구,강북구,강서구,관악구,광진구,구로구,금천구,노원구,도봉구,동대문구,동작구,마포구,서대문구,서초구,성동구,성북구,송파구,양천구,영등포구,용산구,은평구,종로구,중구,중랑구'''.split(',')

# %%
for idx, loc in enumerate(location_list):
    location = Location(id=idx+1, name='서울특별시 '+loc)
    session.add(location)
session.commit()
# Out:
# 2021-08-18 17:40:47,143 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-18 17:40:47,146 INFO sqlalchemy.engine.base.Engine INSERT INTO location (id, name) VALUES (?, ?)
# 2021-08-18 17:40:47,147 INFO sqlalchemy.engine.base.Engine ((1, '서울특별시 강남구'), (2, '서울특별시 강동구'), (3, '서울특별시 강북구'), (4, '서울특별시 강서구'), (5, '서울특별시 관악구'), (6, '서울특별시 광진구'), (7, '서울특별시 구로구'), (8, '서울특별시 금천구')  ... displaying 10 of 25 total bound parameter sets ...  (24, '서울특별시 중구'), (25, '서울특별시 중랑구'))
# 2021-08-18 17:40:47,153 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
for idx, loc in enumerate(location_list):
    print(idx+1, loc )
# Out:
# 1 강남구
# 2 강동구
# 3 강북구
# 4 강서구
# 5 관악구
# 6 광진구
# 7 구로구
# 8 금천구
# 9 노원구
# 10 도봉구
# 11 동대문구
# 12 동작구
# 13 마포구
# 14 서대문구
# 15 서초구
# 16 성동구
# 17 성북구
# 18 송파구
# 19 양천구
# 20 영등포구
# 21 용산구
# 22 은평구
# 23 종로구
# 24 중구
# 25 중랑구

# %%
import pandas as pd

# %%
daycare_center = pd.read_csv('C:/Users/Seogki/GoogleDrive/데이터청년캠퍼스_고려대과정/child-abuse-detection/data/daycare_center.csv')

# %%
daycare_center.drop(columns=['Unnamed: 0'], axis=1, inplace=True)

# %%
daycare_center.head()
# Out:
#             name   phone number                                        address
# 0         예솔어린이집    02-857-1113           서울특별시 금천구 벚꽃로 100 ,105동 102호 (독산제1동)
# 1       반포예원어린이집    02-537-3921           서울특별시 서초구 사평대로 240 ,502동 107호 (반포4동)
# 2       구립푸른어린이집  010-2249-9250  서울특별시 동작구 동작대로35길 46 ,이수푸르지오더프레티움 관리동 (사당제2동)
# 3  서초구립 라클라스어린이집    02-534-2122                     서울특별시 서초구 서초중앙로 206 (반포1동)
# 4      위례바른숲어린이집    02-401-7001                     서울특별시 송파구 위례송파로5길 16 (위례동)

# %%
def find_locid(address):
    location_list = '''강남구,강동구,강북구,강서구,관악구,광진구,구로구,금천구,노원구,도봉구,동대문구,동작구,마포구,서대문구,서초구,성동구,성북구,송파구,양천구,영등포구,용산구,은평구,종로구,중구,중랑구'''.split(',')
    gu = address.split(' ')[1]
    return location_list.index(gu) + 1

# %%
for center in daycare_center.iterrows():
    p_num1,p_num2, p_num3 = center[1]['phone number'].split('-')
    dcc = DaycareCenter(
        name= center[1]['name'],
        chief_staff_name=create_random_name(),
        address=center[1]['address'],
        ph_num1=p_num1,
        ph_num2=p_num2,
        ph_num3=p_num3, 
        loc_id = find_locid(center[1]['address'])
    )
    #print(center[1]['name'],create_random_name(),center[1]['address'],p_num1,p_num2,p_num3,find_locid(center[1]['address']))
    session.add(dcc)

# %%
session.commit()
# Out:
# 2021-08-18 17:40:57,750 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-18 17:40:57,790 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,791 INFO sqlalchemy.engine.base.Engine ('예솔어린이집', '안영숙', '서울특별시 금천구 벚꽃로 100 ,105동 102호 (독산제1동)', '02', '857', '1113', 8)
# 2021-08-18 17:40:57,798 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,801 INFO sqlalchemy.engine.base.Engine ('반포예원어린이집', '오성호', '서울특별시 서초구 사평대로 240 ,502동 107호 (반포4동)', '02', '537', '3921', 15)
# 2021-08-18 17:40:57,803 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,804 INFO sqlalchemy.engine.base.Engine ('구립푸른어린이집', '박미영', '서울특별시 동작구 동작대로35길 46 ,이수푸르지오더프레티움 관리동 (사당제2동)', '010', '2249', '9250', 12)
# 2021-08-18 17:40:57,805 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,806 INFO sqlalchemy.engine.base.Engine ('서초구립 라클라스어린이집', '최경회', '서울특별시 서초구 서초중앙로 206 (반포1동)', '02', '534', '2122', 15)
# 2021-08-18 17:40:57,807 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,808 INFO sqlalchemy.engine.base.Engine ('위례바른숲어린이집', '임동현', '서울특별시 송파구 위례송파로5길 16 (위례동)', '02', '401', '7001', 18)
# 2021-08-18 17:40:57,810 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,810 INFO sqlalchemy.engine.base.Engine ('봄빛어린이집', '임성수', '서울특별시 금천구 벚꽃로 100 ,독산역롯데캐슬아파트 106동 103호 (독산제1동)', '02', '892', '2006', 8)
# 2021-08-18 17:40:57,812 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,813 INFO sqlalchemy.engine.base.Engine ('구립 푸른들어린이집', '권경숙', '서울특별시 은평구 은평로 240 (응암제1동)', '02', '6748', '0202', 22)
# 2021-08-18 17:40:57,814 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,815 INFO sqlalchemy.engine.base.Engine ('구립독산롯데캐슬어린이집', '임성호', '서울특별시 금천구 벚꽃로 100 ,독산역 롯데캐슬아파트 단지내 (독산제1동)', '02', '805', '7605', 8)
# 2021-08-18 17:40:57,816 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,817 INFO sqlalchemy.engine.base.Engine ('근로복지공단 마포어린이집', '서경회', '서울특별시 마포구 연남로 49-1 (연남동)', '02', '322', '7333', 13)
# 2021-08-18 17:40:57,819 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,820 INFO sqlalchemy.engine.base.Engine ('위례아이숲어린이집', '장준영', '서울특별시 송파구 위례북로 30 ,(거여동, 위례포레샤인 17단지) (위례동)', '02', '448', '1718', 18)
# 2021-08-18 17:40:57,821 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,823 INFO sqlalchemy.engine.base.Engine ('구립 꿈여울어린이집', '조종수', '서울특별시 은평구 통일로89길 5-6 (갈현제1동)', '02', '358', '2525', 22)
# 2021-08-18 17:40:57,825 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,827 INFO sqlalchemy.engine.base.Engine ('구립 자양도담어린이집', '조영철', '서울특별시 광진구 아차산로44가길 5 ,(자양동 231-51) (자양제1동)', '02', '455', '7000', 6)
# 2021-08-18 17:40:57,828 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,829 INFO sqlalchemy.engine.base.Engine ('구립 중곡하나어린이집', '김영일', '서울특별시 광진구 동일로76길 59 (중곡제3동)', '02', '465', '1004', 6)
# 2021-08-18 17:40:57,831 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,831 INFO sqlalchemy.engine.base.Engine ('근로복지공단 곰달래어린이집', '서정호', '서울특별시 강서구 곰달래로53길 30-20 (화곡제4동)', '02', '2646', '7142', 4)
# 2021-08-18 17:40:57,833 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,835 INFO sqlalchemy.engine.base.Engine ('원진어린이집', '이정수', '서울특별시 구로구 고척로55길 21 ,(고척동, 원진어린이집) (고척제2동)', '02', '2684', '7444', 7)
# 2021-08-18 17:40:57,837 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,838 INFO sqlalchemy.engine.base.Engine ('성민가정어린이집', '서경회', '서울특별시 강서구 화곡로68길 115 ,101동 111호 (등촌제1동)', '02', '6093', '8643', 4)
# 2021-08-18 17:40:57,840 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,842 INFO sqlalchemy.engine.base.Engine ('산들어린이집', '한준서', '서울특별시 마포구 대흥로24길 24 ,마포프레스티지자이 1단지 내 104동 앞 (염리동)', '02', '2088', '7212', 13)
# 2021-08-18 17:40:57,843 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,844 INFO sqlalchemy.engine.base.Engine ('해들어린이집', '신영식', '서울특별시 마포구 숭문16다길 10-5 ,마포프레스티지자이 2단지 내 203동 옆 (염리동)', '02', '716', '2007', 13)
# 2021-08-18 17:40:57,845 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,847 INFO sqlalchemy.engine.base.Engine ('강남구육아종합지원센터(분원점)', '정순자', '서울특별시 강남구 봉은사로114길 43 (삼성1동)', '02', '568', '1792', 1)
# 2021-08-18 17:40:57,849 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,850 INFO sqlalchemy.engine.base.Engine ('구립 아이샘어린이집', '한정자', '서울특별시 양천구 중앙로43길 14 ,래미안목동아델리체 (신정3동)', '02', '6953', '2911', 19)
# 2021-08-18 17:40:57,852 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,853 INFO sqlalchemy.engine.base.Engine ('구립 아이숲어린이집', '조정웅', '서울특별시 양천구 중앙로43길 14 ,래미안목동아델리체 (신정3동)', '02', '2605', '0061', 19)
# 2021-08-18 17:40:57,855 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,855 INFO sqlalchemy.engine.base.Engine ('로카키즈어린이집', '박준서', '서울특별시 종로구 새문안로2길 10 ,1층 (사직동)', '02', '739', '8042', 23)
# 2021-08-18 17:40:57,857 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,858 INFO sqlalchemy.engine.base.Engine ('숲속별어린이집', '정영철', '서울특별시 서대문구 홍은중앙로3길 9 ,북한산두산위브아파트 (홍은제1동)', '02', '395', '9565', 14)
# 2021-08-18 17:40:57,859 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,860 INFO sqlalchemy.engine.base.Engine ('위례봄어린이집', '최지은', '서울특별시 송파구 위례광장로 121 ,2414동 101호 (위례동)', '02', '400', '8544', 18)
# 2021-08-18 17:40:57,861 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,864 INFO sqlalchemy.engine.base.Engine ('도토리소풍넥슨 대치어린이집', '정영식', '서울특별시 강남구 역삼로90길 25 (대치2동)', '02', '565', '7900', 1)
# 2021-08-18 17:40:57,865 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,866 INFO sqlalchemy.engine.base.Engine ('쿠키즈(coukids) 어린이집', '이건우', '서울특별시 강남구 테헤란로 332 ,HJ타워 3층 (역삼2동)', '02', '6204', '2114', 1)
# 2021-08-18 17:40:57,868 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,868 INFO sqlalchemy.engine.base.Engine ('라온어린이집', '박성민', '서울특별시 영등포구 신길로 29 (대림제1동)', '02', '842', '9376', 20)
# 2021-08-18 17:40:57,870 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,871 INFO sqlalchemy.engine.base.Engine ('삼각지어린이집', '정미영', '서울특별시 용산구 백범로99길 40 ,1,2층 (한강로동)', '02', '6273', '4200', 21)
# 2021-08-18 17:40:57,873 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,874 INFO sqlalchemy.engine.base.Engine ('늘푸른어린이집', '정현정', '서울특별시 서대문구 홍은중앙로1길 100 (홍은제1동)', '02', '6956', '1530', 14)
# 2021-08-18 17:40:57,876 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,876 INFO sqlalchemy.engine.base.Engine ('근로복지공단 등촌어린이집', '오영길', '서울특별시 강서구 강서로56나길 128 (등촌제3동)', '02', '2659', '3370', 4)
# 2021-08-18 17:40:57,878 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,879 INFO sqlalchemy.engine.base.Engine ('해오름어린이집', '강수빈', '서울특별시 동작구 상도로 421 ,현대아파트 108-103 (상도제1동)', '02', '888', '8646', 12)
# 2021-08-18 17:40:57,880 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,881 INFO sqlalchemy.engine.base.Engine ('구립 라온어린이집', '김민재', '서울특별시 강서구 곰달래로53길 112 (화곡제4동)', '02', '2655', '0644', 4)
# 2021-08-18 17:40:57,882 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,883 INFO sqlalchemy.engine.base.Engine ('구립 목3동공원어린이집', '류준혁', '서울특별시 양천구 목동중앙남로16나길 46 (목3동)', '02', '2645', '3220', 19)
# 2021-08-18 17:40:57,884 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,886 INFO sqlalchemy.engine.base.Engine ('구립 아인어린이집', '최지훈', '서울특별시 양천구 목동중앙남로3길 23-1 (목4동)', '02', '2647', '8798', 19)
# 2021-08-18 17:40:57,887 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,889 INFO sqlalchemy.engine.base.Engine ('구립 해든어린이집', '박민수', '서울특별시 양천구 목동남로4길 100 (신정7동)', '02', '6956', '2454', 19)
# 2021-08-18 17:40:57,891 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,892 INFO sqlalchemy.engine.base.Engine ('구립아름어린이집', '장정수', '서울특별시 동작구 양녕로 220 ,상도역롯데캐슬아파트 관리동 (상도제2동)', '02', '821', '2021', 12)
# 2021-08-18 17:40:57,893 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,894 INFO sqlalchemy.engine.base.Engine ('구립지혜어린이집', '임준서', '서울특별시 금천구 시흥대로76길 19 ,골드빌 101호 (시흥제1동)', '02', '891', '7942', 8)
# 2021-08-18 17:40:57,895 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,896 INFO sqlalchemy.engine.base.Engine ('구립트윈파크어린이집', '신정운', '서울특별시 동작구 노량진로23가길 23 ,래미안트윈파크아파트 관리동 (노량진제1동)', '02', '3280', '2320', 12)
# 2021-08-18 17:40:57,897 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,898 INFO sqlalchemy.engine.base.Engine ('꿈동산어린이집', '황민지', '서울특별시 구로구 남부순환로95길 16 ,101동 101호(개봉동, 삼호아파트) (개봉제2동)', '02', '2618', '9382', 7)
# 2021-08-18 17:40:57,901 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,902 INFO sqlalchemy.engine.base.Engine ('느티나무어린이집', '송혜진', '서울특별시 도봉구 도당로13바길 19 (방학제2동)', '02', '3493', '0228', 10)
# 2021-08-18 17:40:57,904 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,905 INFO sqlalchemy.engine.base.Engine ('늘봄어린이집', '송건우', '서울특별시 도봉구 우이천로 487-1 (쌍문제1동)', '02', '996', '5311', 10)
# 2021-08-18 17:40:57,907 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,908 INFO sqlalchemy.engine.base.Engine ('도봉숲어린이집', '안서연', '서울특별시 도봉구 마들로 684-10 (도봉제2동)', '02', '956', '7474', 10)
# 2021-08-18 17:40:57,909 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,910 INFO sqlalchemy.engine.base.Engine ('봄날어린이집', '정준호', '서울특별시 도봉구 덕릉로53길 55 (창제2동)', '02', '6368', '0825', 10)
# 2021-08-18 17:40:57,911 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,912 INFO sqlalchemy.engine.base.Engine ('새빛어린이집', '최성민', '서울특별시 마포구 백범로31길 8 ,202동 1층 (아현동)', '02', '6951', '1317', 13)
# 2021-08-18 17:40:57,913 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,914 INFO sqlalchemy.engine.base.Engine ('서초구립 서초3동하나어린이집', '이정수', '서울특별시 서초구 명달로11길 16 (서초3동)', '02', '523', '6777', 15)
# 2021-08-18 17:40:57,916 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,917 INFO sqlalchemy.engine.base.Engine ('서초구립 한신서래어린이집', '안지민', '서울특별시 서초구 사평대로28길 31 ,101동 108호 (반포4동)', '02', '533', '9631', 15)
# 2021-08-18 17:40:57,918 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,921 INFO sqlalchemy.engine.base.Engine ('서초구립 허니비어린이집', '윤경자', '서울특별시 서초구 서초대로1길 30 ,105동 101호(방배동, 현대아파트) (방배4동)', '02', '535', '7957', 15)
# 2021-08-18 17:40:57,922 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,923 INFO sqlalchemy.engine.base.Engine ('신나라어린이집', '조정순', '서울특별시 중랑구 봉우재로2길 22 (면목제2동)', '02', '432', '5799', 25)
# 2021-08-18 17:40:57,924 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,925 INFO sqlalchemy.engine.base.Engine ('온유한어린이집', '강혜진', '서울특별시 도봉구 덕릉로60자길 22 (창제3동)', '02', '906', '1842', 10)
# 2021-08-18 17:40:57,926 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,927 INFO sqlalchemy.engine.base.Engine ('태양하나어린이집', '최민서', '서울특별시 동대문구 황물로 32 (답십리제1동)', '02', '2245', '9544', 11)
# 2021-08-18 17:40:57,928 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,929 INFO sqlalchemy.engine.base.Engine ('포레나아이어린이집', '이상훈', '서울특별시 노원구 노원로38길 76 (상계10동)', '02', '937', '3263', 9)
# 2021-08-18 17:40:57,930 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,931 INFO sqlalchemy.engine.base.Engine ('해솔어린이집', '서민지', '서울특별시 마포구 서강로 75-16 ,창전동 청년주택 1층 (서강동)', '02', '6956', '0015', 13)
# 2021-08-18 17:40:57,933 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,934 INFO sqlalchemy.engine.base.Engine ('현대열린어린이집', '신은경', '서울특별시 구로구 개봉로20길 6 ,현대아파트 1단지내(개봉역입구쪽) (개봉제2동)', '02', '6091', '1004', 7)
# 2021-08-18 17:40:57,936 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,937 INFO sqlalchemy.engine.base.Engine ('자이숲어린이집', '신준호', '서울특별시 강동구 상일로 55 ,119동 103호(상일동, 고덕자이) (상일제1동)', '02', '441', '9002', 2)
# 2021-08-18 17:40:57,939 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,940 INFO sqlalchemy.engine.base.Engine ('삼성서울병원2 어린이집', '권예은', '서울특별시 강남구 양재대로55길 12 (일원1동)', '02', '3411', '3140', 1)
# 2021-08-18 17:40:57,942 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,943 INFO sqlalchemy.engine.base.Engine ('KB여의도어린이집', '신성호', '서울특별시 영등포구 국제금융로8길 26 ,1층 (여의동)', '02', '6332', '5051', 20)
# 2021-08-18 17:40:57,944 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,945 INFO sqlalchemy.engine.base.Engine ('서울아산병원제2어린이집', '한지원', '서울특별시 송파구 강동대로 13 (풍납2동)', '02', '2045', '3935', 18)
# 2021-08-18 17:40:57,946 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,947 INFO sqlalchemy.engine.base.Engine ('구립 은빛나래어린이집', '권미경', '서울특별시 은평구 서오릉로9길 18 (역촌동)', '02', '3157', '2777', 22)
# 2021-08-18 17:40:57,948 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,949 INFO sqlalchemy.engine.base.Engine ('구립가래여울어린이집', '윤정호', '서울특별시 강동구 아리수로93나길 88 ,강동리버스트8단지아파트관리동 (강일동)', '02', '441', '3690', 2)
# 2021-08-18 17:40:57,950 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,951 INFO sqlalchemy.engine.base.Engine ('구립도로롱어린이집', '윤수빈', '서울특별시 강동구 고덕로98길 160 ,강동리엔파크14단지아파트 관리동 (상일제2동)', '02', '441', '0103', 2)
# 2021-08-18 17:40:57,952 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,952 INFO sqlalchemy.engine.base.Engine ('삼전하늘어린이집', '박준서', '서울특별시 송파구 삼전로10길 21 (삼전동)', '02', '418', '3721', 18)
# 2021-08-18 17:40:57,953 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,954 INFO sqlalchemy.engine.base.Engine ('석촌새싹어린이집', '권현정', '서울특별시 송파구 가락로11길 9-18 (석촌동)', '02', '423', '1860', 18)
# 2021-08-18 17:40:57,955 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,956 INFO sqlalchemy.engine.base.Engine ('구립해뜨는어린이집', '김종수', '서울특별시 강동구 고덕로98길 101 ,강동리엔파크11단지아파트 관리동 (상일제2동)', '02', '3426', '7775', 2)
# 2021-08-18 17:40:57,957 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,958 INFO sqlalchemy.engine.base.Engine ('꿈빛어린이집', '정정식', '서울특별시 마포구 백범로31길 7 ,공덕SK리더스뷰 103동 1층 (아현동)', '02', '6953', '3800', 13)
# 2021-08-18 17:40:57,960 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,960 INFO sqlalchemy.engine.base.Engine ('구립 우장숲어린이집', '임미숙', '서울특별시 강서구 화곡로41길 19 (우장산동)', '02', '2691', '3690', 4)
# 2021-08-18 17:40:57,961 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,962 INFO sqlalchemy.engine.base.Engine ('구립새봄어린이집', '윤민석', '서울특별시 동작구 사당로9길 11-13 (사당제3동)', '02', '532', '3330', 12)
# 2021-08-18 17:40:57,964 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,964 INFO sqlalchemy.engine.base.Engine ('구립은솔어린이집', '서영환', '서울특별시 동작구 상도로 346-1 ,힐스테이트상도 111동 101호 (상도제1동)', '02', '824', '2021', 12)
# 2021-08-18 17:40:57,966 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,966 INFO sqlalchemy.engine.base.Engine ('동심어린이집', '안순자', '서울특별시 중랑구 용마공원로3길 40 (망우본동)', '02', '432', '6461', 25)
# 2021-08-18 17:40:57,968 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,969 INFO sqlalchemy.engine.base.Engine ('푸르니어린이집', '김현준', '서울특별시 구로구 신도림로 16 ,302동 104호 (신도림동)', '02', '2633', '3389', 7)
# 2021-08-18 17:40:57,969 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,970 INFO sqlalchemy.engine.base.Engine ('하영어린이집', '황은정', '서울특별시 구로구 신도림로 16 ,406동102호 (신도림동)', '02', '2672', '3331', 7)
# 2021-08-18 17:40:57,971 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,972 INFO sqlalchemy.engine.base.Engine ('한나어린이집', '장수빈', '서울특별시 서대문구 가재울로 45 ,103동 105호 (남가좌제2동)', '02', '374', '1005', 14)
# 2021-08-18 17:40:57,974 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,975 INFO sqlalchemy.engine.base.Engine ('마곡9 나인어린이집', '전상철', '서울특별시 강서구 공항대로 103 ,엠밸리9단지 관리동 (공항동)', '02', '6956', '5573', 4)
# 2021-08-18 17:40:57,978 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,979 INFO sqlalchemy.engine.base.Engine ('도토리집공동육아어린이집', '박순자', '서울특별시 강북구 삼각산로4길 36 ,나호 (인수동)', '02', '907', '1300', 3)
# 2021-08-18 17:40:57,980 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,981 INFO sqlalchemy.engine.base.Engine ('송파든든어린이집', '권현준', '서울특별시 송파구 위례서이로 25 (위례동)', '02', '407', '0301', 18)
# 2021-08-18 17:40:57,982 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,983 INFO sqlalchemy.engine.base.Engine ('구립또바기어린이집', '신은영', '서울특별시 강동구 상일로 55 ,고덕자이아파트 관리동 (상일제1동)', '02', '441', '3215', 2)
# 2021-08-18 17:40:57,984 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,985 INFO sqlalchemy.engine.base.Engine ('서초구립 래미안리더스원어린이집', '김지원', '서울특별시 서초구 서운로 62 (서초2동)', '02', '522', '6260', 15)
# 2021-08-18 17:40:57,987 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,988 INFO sqlalchemy.engine.base.Engine ('자연아이어린이집', '정병철', '서울특별시 성북구 돌곶이로40길 46 (장위제1동)', '02', '909', '3567', 17)
# 2021-08-18 17:40:57,989 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,990 INFO sqlalchemy.engine.base.Engine ('구립가람슬기어린이집', '임은경', '서울특별시 강동구 올림픽로98가길 12-16 (암사제1동)', '02', '6012', '8957', 2)
# 2021-08-18 17:40:57,991 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,992 INFO sqlalchemy.engine.base.Engine ('신길파크자이솔숲어린이집', '한정호', '서울특별시 영등포구 신길로28길 25 (신길제6동)', '02', '6269', '1900', 20)
# 2021-08-18 17:40:57,993 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,994 INFO sqlalchemy.engine.base.Engine ('구립 염창별하어린이집', '최지은', '서울특별시 강서구 공항대로 543 (염창동)', '02', '3662', '7942', 4)
# 2021-08-18 17:40:57,995 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,995 INFO sqlalchemy.engine.base.Engine ('보배사랑어린이집', '임동현', '서울특별시 구로구 중앙로12길 7 ,101동 101호 (고척제2동)', '02', '2619', '3377', 7)
# 2021-08-18 17:40:57,996 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,997 INFO sqlalchemy.engine.base.Engine ('삼성어린이집', '박예은', '서울특별시 동대문구 한천로26길 43 (장안제1동)', '02', '2243', '5033', 11)
# 2021-08-18 17:40:57,998 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:57,999 INFO sqlalchemy.engine.base.Engine ('거여하나어린이집', '최성진', '서울특별시 송파구 오금로 475 (거여1동)', '02', '402', '2010', 18)
# 2021-08-18 17:40:58,001 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,002 INFO sqlalchemy.engine.base.Engine ('구립 이든아이어린이집', '이상철', '서울특별시 강서구 까치산로18나길 22-1 (화곡본동)', '02', '2605', '0241', 4)
# 2021-08-18 17:40:58,003 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,005 INFO sqlalchemy.engine.base.Engine ('구립사랑그린어린이집', '서진호', '서울특별시 강동구 고덕로98길 29 ,강동리엔파크9단지 관리동 (상일제2동)', '02', '441', '9829', 2)
# 2021-08-18 17:40:58,007 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,008 INFO sqlalchemy.engine.base.Engine ('한별어린이집', '류영철', '서울특별시 서대문구 이화여대8길 123 ,힐스테이트신촌아파트 단지 내 (북아현동)', '02', '392', '6001', 14)
# 2021-08-18 17:40:58,009 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,010 INFO sqlalchemy.engine.base.Engine ('구립강동해밀어린이집', '조민수', '서울특별시 강동구 아리수로93가길 77 ,강동리버스트6단지아파트 관리동 (강일동)', '02', '426', '8861', 2)
# 2021-08-18 17:40:58,011 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,012 INFO sqlalchemy.engine.base.Engine ('구립해봄어린이집', '김준호', '서울특별시 강동구 아리수로93가길 70 ,강동리버스트7단지아파트 관리동 (강일동)', '02', '426', '9370', 2)
# 2021-08-18 17:40:58,014 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,014 INFO sqlalchemy.engine.base.Engine ('구립대우주어린이집', '전상훈', '서울특별시 강서구 화곡로13길 107 ,135동 101호 (화곡제3동)', '02', '2605', '7313', 4)
# 2021-08-18 17:40:58,015 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,017 INFO sqlalchemy.engine.base.Engine ('서초구립 센트럴아이파크어린이집', '황영일', '서울특별시 서초구 반포대로18길 36 (서초3동)', '02', '2088', '7137', 15)
# 2021-08-18 17:40:58,018 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,018 INFO sqlalchemy.engine.base.Engine ('도토리소풍넥슨 강남어린이집', '전은영', '서울특별시 강남구 강남대로110길 36 ,(역삼동) (역삼1동)', '02', '538', '1026', 1)
# 2021-08-18 17:40:58,019 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,020 INFO sqlalchemy.engine.base.Engine ('신길힐스테이트나래어린이집', '정건우', '서울특별시 영등포구 신길로28길 9 (신길제4동)', '02', '6672', '8330', 20)
# 2021-08-18 17:40:58,021 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,022 INFO sqlalchemy.engine.base.Engine ('위례푸른숲어린이집', '이은영', '서울특별시 송파구 위례북로4길 12 (위례동)', '02', '409', '7942', 18)
# 2021-08-18 17:40:58,023 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,027 INFO sqlalchemy.engine.base.Engine ('현대오토에버 늘해랑어린이집', '윤지영', '서울특별시 강남구 삼성로84길 13 (대치2동)', '02', '3453', '0053', 1)
# 2021-08-18 17:40:58,028 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,030 INFO sqlalchemy.engine.base.Engine ('쿠팡(위례)어린이집', '황은영', '서울특별시 송파구 위례광장로 188 ,아이온스퀘어 2F (위례동)', '02', '400', '7790', 18)
# 2021-08-18 17:40:58,031 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,032 INFO sqlalchemy.engine.base.Engine ('구립 샘물어린이집', '김서연', '서울특별시 광진구 뚝섬로58길 56 ,101호 (자양제2동)', '02', '3437', '7737', 6)
# 2021-08-18 17:40:58,033 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,034 INFO sqlalchemy.engine.base.Engine ('포레스트어린이집', '장준혁', '서울특별시 강남구 개포로 264 (개포제4동)', '02', '2058', '3788', 1)
# 2021-08-18 17:40:58,035 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,036 INFO sqlalchemy.engine.base.Engine ('거여사과나무어린이집', '윤준영', '서울특별시 송파구 거마로 41 ,302동 101호(거여동, 현대3차아파트) (거여1동)', '02', '3402', '3425', 18)
# 2021-08-18 17:40:58,038 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,039 INFO sqlalchemy.engine.base.Engine ('빛의숲어린이집', '윤병철', '서울특별시 강남구 논현로158길 19 ,1층 (압구정동)', '02', '542', '5857', 1)
# 2021-08-18 17:40:58,041 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,041 INFO sqlalchemy.engine.base.Engine ('송파아이숲어린이집', '신종수', '서울특별시 송파구 오금로 551 ,205동 104호 (거여2동)', '02', '400', '6079', 18)
# 2021-08-18 17:40:58,043 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,043 INFO sqlalchemy.engine.base.Engine ('큰나래어린이집', '이성진', '서울특별시 용산구 서빙고로 17 ,102동 1,2,3층 (한강로동)', '02', '797', '7703', 21)
# 2021-08-18 17:40:58,045 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,046 INFO sqlalchemy.engine.base.Engine ('구립늘해랑어린이집', '류성수', '서울특별시 강동구 고덕로 399 ,고덕센트럴푸르지오아파트 관리동 (고덕제2동)', '02', '429', '7942', 2)
# 2021-08-18 17:40:58,047 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,048 INFO sqlalchemy.engine.base.Engine ('꿈빛 어린이집', '서은영', '서울특별시 성북구 종암로21길 127 ,101동 101호 (종암동)', '02', '6227', '4960', 17)
# 2021-08-18 17:40:58,050 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,051 INFO sqlalchemy.engine.base.Engine ('라온어린이집', '신혜진', '서울특별시 중랑구 동일로91길 23 (면목제5동)', '02', '432', '5592', 25)
# 2021-08-18 17:40:58,051 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,055 INFO sqlalchemy.engine.base.Engine ('사가정 아이파크어린이집', '김영숙', '서울특별시 중랑구 동일로92길 40 (면목제5동)', '02', '496', '8077', 25)
# 2021-08-18 17:40:58,056 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,057 INFO sqlalchemy.engine.base.Engine ('새솔아델포레어린이집', '조영식', '서울특별시 영등포구 신길로 29 (대림제1동)', '02', '6334', '0202', 20)
# 2021-08-18 17:40:58,058 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,059 INFO sqlalchemy.engine.base.Engine ('신아푸르지오 어린이집', '서현정', '서울특별시 은평구 연서로 455 ,제각말 5단지 푸르지오 관리동(진관동) (진관동)', '02', '358', '0404', 22)
# 2021-08-18 17:40:58,060 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,060 INFO sqlalchemy.engine.base.Engine ('서울도봉경찰서어린이집', '장서현', '서울특별시 도봉구 노해로 403 ,서울도봉경찰서어린이집 (창제4동)', '02', '906', '8190', 10)
# 2021-08-18 17:40:58,061 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,062 INFO sqlalchemy.engine.base.Engine ('중앙그룹직장어린이집', '안성민', '서울특별시 마포구 월드컵북로 375 ,1,2층 (상암동)', '070', '8672', '9249', 13)
# 2021-08-18 17:40:58,063 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,064 INFO sqlalchemy.engine.base.Engine ('카페24직장어린이집', '오유진', '서울특별시 관악구 보라매로3길 23 ,2층(카페24직장어린이집) (보라매동)', '02', '6279', '2411', 5)
# 2021-08-18 17:40:58,065 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,066 INFO sqlalchemy.engine.base.Engine ('별하어린이집', '최상철', '서울특별시 구로구 항동로 68 ,하버라인9단지 관리동 내 (항동)', '02', '2682', '0996', 7)
# 2021-08-18 17:40:58,067 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,067 INFO sqlalchemy.engine.base.Engine ('당산2동센트럴아이파크별하어린이집', '한민재', '서울특별시 영등포구 영신로 247 ,107동 관리동 (당산제2동)', '02', '2135', '2653', 20)
# 2021-08-18 17:40:58,068 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,069 INFO sqlalchemy.engine.base.Engine ('방이즐거운어린이집', '장성호', '서울특별시 송파구 가락로39길 6 ,(방이동) (방이2동)', '02', '413', '5277', 18)
# 2021-08-18 17:40:58,069 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,070 INFO sqlalchemy.engine.base.Engine ('송파파크센트럴어린이집', '박서연', '서울특별시 송파구 오금로 551 (거여2동)', '02', '403', '7700', 18)
# 2021-08-18 17:40:58,070 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,071 INFO sqlalchemy.engine.base.Engine ('구립키즈맘어린이집', '장민재', '서울특별시 관악구 봉천로23나길 35 ,101호 (보라매동)', '02', '874', '0761', 5)
# 2021-08-18 17:40:58,072 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,073 INFO sqlalchemy.engine.base.Engine ('해바라기어린이집', '송예은', '서울특별시 구로구 항동로 8 ,관리동 (항동)', '02', '2060', '5887', 7)
# 2021-08-18 17:40:58,074 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,075 INFO sqlalchemy.engine.base.Engine ('현대모비스모아어린이집', '오성호', '서울특별시 강남구 테헤란로13길 34 (역삼1동)', '02', '3454', '0062', 1)
# 2021-08-18 17:40:58,076 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,077 INFO sqlalchemy.engine.base.Engine ('참누리어린이집', '신상철', '서울특별시 구로구 경인로 302 ,관리동 (개봉동,개봉역센트레빌레우스 임대아파트) (개봉제1동)', '02', '2612', '2021', 7)
# 2021-08-18 17:40:58,078 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,079 INFO sqlalchemy.engine.base.Engine ('구립강동든든어린이집', '전경회', '서울특별시 강동구 아리수로93가길 110 ,관리동 (강일동)', '02', '442', '2807', 2)
# 2021-08-18 17:40:58,080 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,080 INFO sqlalchemy.engine.base.Engine ('당산2동은솔어린이집', '송예준', '서울특별시 영등포구 당산로42길 23 (당산제2동)', '02', '2636', '5630', 20)
# 2021-08-18 17:40:58,081 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,082 INFO sqlalchemy.engine.base.Engine ('새우개 하나어린이집', '최수빈', '서울특별시 중랑구 용마산로139다길 17 (신내1동)', '02', '438', '1318', 25)
# 2021-08-18 17:40:58,084 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,084 INFO sqlalchemy.engine.base.Engine ('서울지방국세청 우리누리어린이집', '황건우', '서울특별시 종로구 종로5길 86 (종로1.2.3.4가동)', '02', '739', '5100', 23)
# 2021-08-18 17:40:58,085 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,090 INFO sqlalchemy.engine.base.Engine ('서초구립 반포센트럴자이어린이집', '안미숙', '서울특별시 서초구 반포대로 310-6 ,(반포센트럴자이어린이집) (반포3동)', '02', '533', '8801', 15)
# 2021-08-18 17:40:58,091 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,092 INFO sqlalchemy.engine.base.Engine ('아이누리어린이집', '황지훈', '서울특별시 성북구 숭인로 16 ,103동 101호 (길음제2동)', '02', '982', '3949', 17)
# 2021-08-18 17:40:58,093 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,094 INFO sqlalchemy.engine.base.Engine ('두빛나래터발도르프어린이집', '전정호', '서울특별시 강서구 등촌로39마길 52 (등촌제2동)', '02', '2653', '6986', 4)
# 2021-08-18 17:40:58,095 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,095 INFO sqlalchemy.engine.base.Engine ('서울남부지방법원 직장어린이집', '전영일', '서울특별시 양천구 신월로 386 ,별관 5층 (신정1동)', '02', '2192', '1930', 19)
# 2021-08-18 17:40:58,096 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,097 INFO sqlalchemy.engine.base.Engine ('아이키움문래어린이집', '최성진', '서울특별시 영등포구 선유로9길 30 ,102동 1층(문래동6가) (문래동)', '02', '6397', '7955', 20)
# 2021-08-18 17:40:58,097 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,098 INFO sqlalchemy.engine.base.Engine ('구립 물빛캐슬어린이집', '임순자', '서울특별시 은평구 수색로 300 (수색동)', '02', '6951', '2081', 22)
# 2021-08-18 17:40:58,099 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,105 INFO sqlalchemy.engine.base.Engine ('다올어린이집', '황정수', '서울특별시 마포구 양화로 72 ,1층 (서교동)', '02', '332', '2322', 13)
# 2021-08-18 17:40:58,106 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,107 INFO sqlalchemy.engine.base.Engine ('늘봄어린이집', '오혜진', '서울특별시 동대문구 외대역동로1길 60-3 ,휘경해모로 관리동 (휘경제1동)', '02', '3390', '3094', 11)
# 2021-08-18 17:40:58,108 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,109 INFO sqlalchemy.engine.base.Engine ('구립 가온어린이집', '황건우', '서울특별시 양천구 남부순환로83길 17 ,목동센트럴아이파크위브아파트 1단지 (신월6동)', '02', '2602', '2484', 19)
# 2021-08-18 17:40:58,110 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,111 INFO sqlalchemy.engine.base.Engine ('구립 나래어린이집', '신종수', '서울특별시 양천구 남부순환로83길 18 ,목동센트럴아이파크위브아파트 2단지 (신월6동)', '02', '2603', '4110', 19)
# 2021-08-18 17:40:58,112 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,113 INFO sqlalchemy.engine.base.Engine ('구립 마루어린이집', '류민지', '서울특별시 양천구 남부순환로83길 47 ,목동센트럴아이파크위브아파트 4단지 (신월6동)', '02', '2604', '4301', 19)
# 2021-08-18 17:40:58,114 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,115 INFO sqlalchemy.engine.base.Engine ('구립에코포레어린이집', '임미숙', '서울특별시 강동구 천중로 253 ,이편한세상강동에코포레아파트 관리동 1층 (길동)', '02', '470', '0633', 2)
# 2021-08-18 17:40:58,117 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,118 INFO sqlalchemy.engine.base.Engine ('날아라어린이집', '정준영', '서울특별시 구로구 부광로 96-16 (항동)', '02', '2066', '7114', 7)
# 2021-08-18 17:40:58,119 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,120 INFO sqlalchemy.engine.base.Engine ('한나무어린이집', '김정웅', '서울특별시 도봉구 노해로66길 21 ,103동 105호(창동, 삼성래미안아파트) (창제1동)', '02', '995', '2447', 10)
# 2021-08-18 17:40:58,121 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,123 INFO sqlalchemy.engine.base.Engine ('거여키즈어린이집', '윤광수', '서울특별시 송파구 거마로 41 ,303동 102호(거여동, 현대3차아파트) (거여1동)', '02', '408', '6198', 18)
# 2021-08-18 17:40:58,125 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,127 INFO sqlalchemy.engine.base.Engine ('구립다움어린이집', '임영진', '서울특별시 동작구 사당로 90 ,사당롯데캐슬골든포레 관리동 1층 (사당제5동)', '02', '582', '2990', 12)
# 2021-08-18 17:40:58,128 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,131 INFO sqlalchemy.engine.base.Engine ('영등포든든어린이집', '권은영', '서울특별시 영등포구 대림로35가길 9 (대림제3동)', '02', '842', '2021', 20)
# 2021-08-18 17:40:58,133 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,134 INFO sqlalchemy.engine.base.Engine ('구립 응암샛별어린이집', '전서연', '서울특별시 은평구 은평로 220 (응암제1동)', '02', '354', '5208', 22)
# 2021-08-18 17:40:58,135 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,136 INFO sqlalchemy.engine.base.Engine ('구립 응암행복어린이집', '권정남', '서울특별시 은평구 은평로 220 (응암제1동)', '02', '353', '0701', 22)
# 2021-08-18 17:40:58,137 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,138 INFO sqlalchemy.engine.base.Engine ('신촌그랑어린이집', '장지은', '서울특별시 마포구 대흥로 175 ,관리동 (대흥동)', '02', '6949', '0277', 13)
# 2021-08-18 17:40:58,139 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,141 INFO sqlalchemy.engine.base.Engine ('이삭숲어린이집', '정지은', '서울특별시 강동구 동남로82길 29-8 ,이삭숲어린이집 (고덕제2동)', '02', '441', '2914', 2)
# 2021-08-18 17:40:58,142 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,143 INFO sqlalchemy.engine.base.Engine ('서대문든든어린이집', '안정수', '서울특별시 서대문구 거북골로 100 ,래미안루센티아아파트 (남가좌제2동)', '02', '306', '2020', 14)
# 2021-08-18 17:40:58,144 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,144 INFO sqlalchemy.engine.base.Engine ('한샘어린이집', '권영철', '서울특별시 서초구 방배로 285 ,한샘빌딩 (방배본동)', '02', '6908', '4051', 15)
# 2021-08-18 17:40:58,145 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:40:58,146 INFO sqlalchemy.engine.base.Engine ('행복타운어린이집', '전민수', '서울특별시 마포구 마포대로 144 ,마포T타운 2층 (공덕동)', '070', '7470', '3598', 13)
# ...
# 2021-08-18 17:41:09,066 INFO sqlalchemy.engine.base.Engine ('햇살어린이집', '김정수', '서울특별시 동대문구 청계천로 547 ,(용두동 696-9) (용신동)', '02', '962', '5519', 11)
# 2021-08-18 17:41:09,069 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,071 INFO sqlalchemy.engine.base.Engine ('자양어린이집', '정준혁', '서울특별시 광진구 자양번영로 35 ,(자양동) (자양제3동)', '02', '452', '0748', 6)
# 2021-08-18 17:41:09,072 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,073 INFO sqlalchemy.engine.base.Engine ('천호어린이집', '윤미영', '서울특별시 강동구 천중로35길 60 ,(천호동 48-2호) (천호제1동)', '02', '483', '1439', 2)
# 2021-08-18 17:41:09,074 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,075 INFO sqlalchemy.engine.base.Engine ('월계3동어린이집', '전정수', '서울특별시 노원구 마들로 31 ,3동(월계동, 한진한화그랑빌) (월계3동)', '02', '973', '8181', 9)
# 2021-08-18 17:41:09,076 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,077 INFO sqlalchemy.engine.base.Engine ('이태원어린이집', '박미숙', '서울특별시 용산구 녹사평대로40나길 38-3 (이태원제2동)', '02', '798', '2592', 21)
# 2021-08-18 17:41:09,078 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,079 INFO sqlalchemy.engine.base.Engine ('서강어린이집', '조준혁', '서울특별시 마포구 와우산로30길 79 ,(창전동) (서강동)', '02', '337', '1394', 13)
# 2021-08-18 17:41:09,080 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,081 INFO sqlalchemy.engine.base.Engine ('서계어린이집', '김예은', '서울특별시 용산구 청파로93길 25 ,서계어린이집 (청파동)', '02', '715', '6046', 21)
# 2021-08-18 17:41:09,082 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,082 INFO sqlalchemy.engine.base.Engine ('누상어린이집', '이영식', '서울특별시 종로구 옥인길 23-4 ,(누상동) (청운효자동)', '02', '738', '6711', 23)
# 2021-08-18 17:41:09,083 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,084 INFO sqlalchemy.engine.base.Engine ('창전어린이집', '류예준', '서울특별시 마포구 창전로 69 ,(창전동) (서강동)', '02', '324', '5131', 13)
# 2021-08-18 17:41:09,085 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,086 INFO sqlalchemy.engine.base.Engine ('인왕어린이집', '윤민지', '서울특별시 종로구 통일로18길 9 ,인왕산 아이파크단지내 (무악동)', '02', '738', '8577', 23)
# 2021-08-18 17:41:09,088 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,089 INFO sqlalchemy.engine.base.Engine ('구립탑골어린이집', '김예준', '서울특별시 금천구 금하로 764 ,(시흥동) (시흥제2동)', '02', '803', '2070', 8)
# 2021-08-18 17:41:09,091 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,092 INFO sqlalchemy.engine.base.Engine ('구립선재어린이집', '김정자', '서울특별시 동작구 노량진로32길 62 ,(본동) (노량진제1동)', '02', '815', '0274', 12)
# 2021-08-18 17:41:09,094 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,095 INFO sqlalchemy.engine.base.Engine ('양평2동어린이집', '조정수', '서울특별시 영등포구 선유로53길 20-7 ,(양평동4가) (양평제2동)', '02', '2634', '7383', 20)
# 2021-08-18 17:41:09,096 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,098 INFO sqlalchemy.engine.base.Engine ('구립율곡어린이집', '조정호', '서울특별시 관악구 신우길 1 ,(신림동) [삼성동] (삼성동)', '02', '889', '7682', 5)
# 2021-08-18 17:41:09,099 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,100 INFO sqlalchemy.engine.base.Engine ('남산숲어린이집', '이영일', '서울특별시 중구 동호로5길 193 ,남산숲어린이집 (신당동) (약수동)', '02', '2234', '2753', 24)
# 2021-08-18 17:41:09,101 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,102 INFO sqlalchemy.engine.base.Engine ('이화어린이집', '박영길', '서울특별시 중랑구 면목로27길 85 ,(면목동) (면목제4동)', '02', '432', '4425', 25)
# 2021-08-18 17:41:09,104 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,105 INFO sqlalchemy.engine.base.Engine ('구립 마장어린이집', '최준호', '서울특별시 성동구 마장로44길 10 ,(마장동) (마장동)', '02', '2293', '9394', 16)
# 2021-08-18 17:41:09,106 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,106 INFO sqlalchemy.engine.base.Engine ('노원어린이집', '오종수', '서울특별시 노원구 동일로239다길 23 ,(상계동) (상계1동)', '02', '936', '0649', 9)
# 2021-08-18 17:41:09,107 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,108 INFO sqlalchemy.engine.base.Engine ('장안어린이집', '박지영', '서울특별시 동대문구 천호대로89길 58 ,(장안동) (장안제1동)', '02', '2212', '5178', 11)
# 2021-08-18 17:41:09,108 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,109 INFO sqlalchemy.engine.base.Engine ('구립삼양어린이집', '임정호', '서울특별시 강북구 삼양로64길 32 -14 ,구립삼양어린이집 (삼양동)', '02', '989', '0259', 3)
# 2021-08-18 17:41:09,112 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,113 INFO sqlalchemy.engine.base.Engine ('낙산어린이집', '서준혁', '서울특별시 종로구 창신길 210-11 ,낙산어린이집 (창신동) (창신제2동)', '02', '765', '1268', 23)
# 2021-08-18 17:41:09,114 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,115 INFO sqlalchemy.engine.base.Engine ('무악어린이집', '조지원', '서울특별시 종로구 통일로18길 64 ,(무악동) (무악동)', '02', '736', '8003', 23)
# 2021-08-18 17:41:09,116 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,117 INFO sqlalchemy.engine.base.Engine ('구립합실어린이집', '송지훈', '서울특별시 관악구 광신길 113 ,(신림동) [삼성동] (삼성동)', '02', '878', '0254', 5)
# 2021-08-18 17:41:09,118 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,119 INFO sqlalchemy.engine.base.Engine ('구립 서마어린이집', '류정호', '서울특별시 성동구 청계천로 546 ,(마장동) (마장동)', '02', '2293', '5369', 16)
# 2021-08-18 17:41:09,121 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,122 INFO sqlalchemy.engine.base.Engine ('구립도담어린이집', '전정순', '서울특별시 관악구 청림3길 37 ,(봉천동) [청림동] (청림동)', '02', '886', '2240', 5)
# 2021-08-18 17:41:09,122 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,123 INFO sqlalchemy.engine.base.Engine ('마천어린이집', '오민수', '서울특별시 송파구 마천로61다길 28-7 (마천1동)', '02', '406', '2300', 18)
# 2021-08-18 17:41:09,124 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,125 INFO sqlalchemy.engine.base.Engine ('황학어린이집', '안지혜', '서울특별시 중구 난계로15길 23 ,(황학동) (황학동)', '02', '2234', '6840', 24)
# 2021-08-18 17:41:09,126 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,127 INFO sqlalchemy.engine.base.Engine ('상봉어린이집', '송정웅', '서울특별시 중랑구 상봉중앙로6길 57 ,(상봉동) (상봉제1동)', '02', '432', '3421', 25)
# 2021-08-18 17:41:09,128 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,128 INFO sqlalchemy.engine.base.Engine ('구립중앙어린이집', '류정식', '서울특별시 관악구 봉천로41길 35 ,(봉천동) [중앙동] (중앙동)', '02', '884', '5861', 5)
# 2021-08-18 17:41:09,129 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,130 INFO sqlalchemy.engine.base.Engine ('금화어린이집', '이미경', '서울특별시 서대문구 독립문로10길 15 ,(천연동) (천연동)', '02', '392', '0212', 14)
# 2021-08-18 17:41:09,131 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,132 INFO sqlalchemy.engine.base.Engine ('구립송천동어린이집', '강광수', '서울특별시 강북구 솔샘로60길 21 ,(미아동) (송천동)', '02', '981', '7391', 3)
# 2021-08-18 17:41:09,133 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,134 INFO sqlalchemy.engine.base.Engine ('구립문화어린이집', '안민석', '서울특별시 동작구 사당로13길 24 ,(사당동) (사당제3동)', '02', '534', '0175', 12)
# 2021-08-18 17:41:09,135 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,136 INFO sqlalchemy.engine.base.Engine ('구립신림어린이집', '안민서', '서울특별시 관악구 난곡로 67 ,(신림동) [난향동] (난향동)', '02', '853', '4487', 5)
# 2021-08-18 17:41:09,137 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,138 INFO sqlalchemy.engine.base.Engine ('동대문어린이집', '정정순', '서울특별시 동대문구 사가정로2길 13 ,(답십리동) (답십리제1동)', '02', '2213', '7994', 11)
# 2021-08-18 17:41:09,139 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,139 INFO sqlalchemy.engine.base.Engine ('안암어린이집', '안영일', '서울특별시 성북구 고려대로8길 5 ,(안암동2가) (안암동)', '02', '923', '5046', 17)
# 2021-08-18 17:41:09,140 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,141 INFO sqlalchemy.engine.base.Engine ('도봉도선어린이집', '서경회', '서울특별시 도봉구 마들로 756 ,(도봉동) (도봉제2동)', '02', '954', '4311', 10)
# 2021-08-18 17:41:09,141 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,142 INFO sqlalchemy.engine.base.Engine ('푸른하늘어린이집', '박영환', '서울특별시 동대문구 답십리로66길 75-4 ,(장안동 393-2) (장안제1동)', '02', '2212', '1036', 11)
# 2021-08-18 17:41:09,144 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,146 INFO sqlalchemy.engine.base.Engine ('진선미어린이집', '이준혁', '서울특별시 마포구 마포대로4나길 28 ,진선미어린이집 (도화동)', '02', '714', '1486', 13)
# 2021-08-18 17:41:09,149 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,150 INFO sqlalchemy.engine.base.Engine ('성북어린이집', '장정순', '서울특별시 성북구 동소문동1가 성북로4길 13-2 (성북동)', '02', '742', '1097', 17)
# 2021-08-18 17:41:09,151 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,152 INFO sqlalchemy.engine.base.Engine ('혜림어린이집', '류종수', '서울특별시 강동구 천중로39길 77 ,(천호동47-23) (천호제1동)', '02', '477', '1015', 2)
# 2021-08-18 17:41:09,154 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,154 INFO sqlalchemy.engine.base.Engine ('용산어린이집', '송종수', '서울특별시 용산구 한강로2가 한강대로38길 28 ,용산어린이집 (한강로동)', '02', '795', '0432', 21)
# 2021-08-18 17:41:09,155 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,156 INFO sqlalchemy.engine.base.Engine ('서대문어린이집', '윤정수', '서울특별시 서대문구 증가로29길 30-42 (북가좌제2동)', '02', '372', '0547', 14)
# 2021-08-18 17:41:09,157 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,158 INFO sqlalchemy.engine.base.Engine ('창신어린이집', '윤혜진', '서울특별시 종로구 창신5길 22 ,(창신동) (창신제1동)', '02', '743', '6302', 23)
# 2021-08-18 17:41:09,159 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,160 INFO sqlalchemy.engine.base.Engine ('구립 은아새 어린이집', '이영자', '서울특별시 은평구 불광천길 470-11 (응암제3동)', '02', '386', '4498', 22)
# 2021-08-18 17:41:09,161 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,162 INFO sqlalchemy.engine.base.Engine ('마포어린이집', '안진호', '서울특별시 마포구 양화로18안길 21 ,(동교동) (서교동)', '02', '334', '4743', 13)
# 2021-08-18 17:41:09,163 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,164 INFO sqlalchemy.engine.base.Engine ('명인어린이집', '이성호', '서울특별시 중랑구 면목로53길 70 ,(면목동) (면목제3.8동)', '02', '434', '4651', 25)
# 2021-08-18 17:41:09,165 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,169 INFO sqlalchemy.engine.base.Engine ('역삼가애어린이집', '서혜진', '서울특별시 강남구 도곡로37길 15 ,(역삼동) (역삼제2동)', '02', '568', '1623', 1)
# 2021-08-18 17:41:09,170 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,171 INFO sqlalchemy.engine.base.Engine ('성동어린이집', '황도현', '서울특별시 광진구 능동로3마길 1 ,(자양동, 자양) (자양제4동)', '02', '463', '0942', 6)
# 2021-08-18 17:41:09,172 INFO sqlalchemy.engine.base.Engine INSERT INTO daycare_center (name, chief_staff_name, address, ph_num1, ph_num2, ph_num3, loc_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-08-18 17:41:09,172 INFO sqlalchemy.engine.base.Engine ('항동어린이집', '전영자', '서울특별시 구로구 연동로 284 (항동)', '02', '2614', '4459', 7)
# 2021-08-18 17:41:09,269 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
violence_vid_name = [
    '태양하나어린이집_2021-08-18_16:47:52 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:04 PM.mp4',
    '태양하나어린이집_2021-08-18_16:46:52 PM.mp4'
]
uncertain_vid_name =[
    '태양하나어린이집_2021-08-18_16:46:54 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:05 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:08 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:09 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:13 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:21 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:23 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:26 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:28 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:32 PM.mp4',
    '태양하나어린이집_2021-08-18_16:47:51 PM.mp4'
]

# %%
tmp = violence_vid_name[0]

# %%
temp = tmp.split('태양하나어린이집_')[-1].split('.mp4')[0]

# %%
temp
# Out:
# '2021-08-18_16:47:52 PM'

# %%
time.mktime(datetime.datetime.strptime(temp, "%Y-%m-%d_%H:%M:%S PM").timetuple())
# Out:
# 1629272872.0

# %%
convert_datetime(1629272872)
# Out:
# '2021-08-18 16:47:52'

# %%
np.r

# %%
np.random.randint(80,100) + np.random.randint(0,99) * 0.01
# Out:
# 99.59

# %%
# 0 not check
# 1 checked
# 2 police reported

for vid in uncertain_vid_name[8:]:
    temp = vid.split('태양하나어린이집_')[-1].split('.mp4')[0]
    time_ = time.mktime(datetime.datetime.strptime(temp, "%Y-%m-%d_%H:%M:%S PM").timetuple())
    video = Video(
        detection_time = time_,
        name = vid,
        accuracy = np.random.randint(50,80) + np.random.randint(0,99) * 0.01,
        status = '1',
        loc_id = 11,
        dc_id = 50
    )
    session.add(video)

# %%
session.commit()
# Out:
# 2021-08-18 18:00:18,416 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-18 18:00:18,419 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:00:18,420 INFO sqlalchemy.engine.base.Engine (1629272814.0, '태양하나어린이집_2021-08-18_16:46:54 PM.mp4', 97.0, '0', 11, 50)
# 2021-08-18 18:00:18,425 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:00:18,426 INFO sqlalchemy.engine.base.Engine (1629272825.0, '태양하나어린이집_2021-08-18_16:47:05 PM.mp4', 95.0, '0', 11, 50)
# 2021-08-18 18:00:18,428 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:00:18,428 INFO sqlalchemy.engine.base.Engine (1629272828.0, '태양하나어린이집_2021-08-18_16:47:08 PM.mp4', 87.0, '0', 11, 50)
# 2021-08-18 18:00:18,429 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:00:18,430 INFO sqlalchemy.engine.base.Engine (1629272829.0, '태양하나어린이집_2021-08-18_16:47:09 PM.mp4', 86.0, '0', 11, 50)
# 2021-08-18 18:00:18,432 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:00:18,432 INFO sqlalchemy.engine.base.Engine (1629272833.0, '태양하나어린이집_2021-08-18_16:47:13 PM.mp4', 93.5, '0', 11, 50)
# 2021-08-18 18:00:18,433 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:00:18,434 INFO sqlalchemy.engine.base.Engine (1629272841.0, '태양하나어린이집_2021-08-18_16:47:21 PM.mp4', 93.94, '0', 11, 50)
# 2021-08-18 18:00:18,434 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:00:18,436 INFO sqlalchemy.engine.base.Engine (1629272843.0, '태양하나어린이집_2021-08-18_16:47:23 PM.mp4', 99.03, '0', 11, 50)
# 2021-08-18 18:00:18,437 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:00:18,437 INFO sqlalchemy.engine.base.Engine (1629272848.0, '태양하나어린이집_2021-08-18_16:47:28 PM.mp4', 95.98, '1', 11, 50)
# 2021-08-18 18:00:18,438 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:00:18,439 INFO sqlalchemy.engine.base.Engine (1629272852.0, '태양하나어린이집_2021-08-18_16:47:32 PM.mp4', 80.93, '1', 11, 50)
# 2021-08-18 18:00:18,440 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:00:18,440 INFO sqlalchemy.engine.base.Engine (1629272871.0, '태양하나어린이집_2021-08-18_16:47:51 PM.mp4', 80.35, '1', 11, 50)
# 2021-08-18 18:00:18,441 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# 0 not check
# 1 checked
# 2 police reported

for vid in violence_vid_name:
    temp = vid.split('태양하나어린이집_')[-1].split('.mp4')[0]
    time_ = time.mktime(datetime.datetime.strptime(temp, "%Y-%m-%d_%H:%M:%S PM").timetuple())
    video = Video(
        detection_time = time_,
        name = vid,
        accuracy = np.random.randint(80,100) + np.random.randint(0,99) * 0.01,
        status = '2',
        loc_id = 11,
        dc_id = 50
    )
    session.add(video)

# %%
session.commit()
# Out:
# 2021-08-18 18:01:27,878 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-18 18:01:27,879 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:01:27,880 INFO sqlalchemy.engine.base.Engine (1629272872.0, '태양하나어린이집_2021-08-18_16:47:52 PM.mp4', 97.43, '2', 11, 50)
# 2021-08-18 18:01:27,886 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:01:27,886 INFO sqlalchemy.engine.base.Engine (1629272824.0, '태양하나어린이집_2021-08-18_16:47:04 PM.mp4', 98.89, '2', 11, 50)
# 2021-08-18 18:01:27,888 INFO sqlalchemy.engine.base.Engine INSERT INTO video (detection_time, name, accuracy, status, loc_id, dc_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:01:27,889 INFO sqlalchemy.engine.base.Engine (1629272812.0, '태양하나어린이집_2021-08-18_16:46:52 PM.mp4', 83.0, '2', 11, 50)
# 2021-08-18 18:01:27,890 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
video1 = ReportList(
    time = 1629272872+ 50,
    police_name = '청량리파출소',
    status = '출동',
    loc_id = 11,
    dc_id = 50,
    vid_id = 11
)
video2 = ReportList(
    time = 1629272824+ 23,
    police_name = '답십리지구대',
    status = '현장 종결',
    loc_id = 11,
    dc_id = 50,
    vid_id = 12
)
video3 = ReportList(
    time = 1629272812 +19,
    police_name = '휘경파출소',
    status = '현장 종결',
    loc_id = 11,
    dc_id = 50,
    vid_id = 13
)

# %%
session.add(video1)
session.add(video2)
session.add(video3)
session.commit()
# Out:
# 2021-08-18 18:11:51,289 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-18 18:11:51,291 INFO sqlalchemy.engine.base.Engine INSERT INTO report_list (time, police_name, status, loc_id, dc_id, vid_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:11:51,292 INFO sqlalchemy.engine.base.Engine (1629272922, '청량리파출소', '출동', 11, 50, 11)
# 2021-08-18 18:11:51,297 INFO sqlalchemy.engine.base.Engine INSERT INTO report_list (time, police_name, status, loc_id, dc_id, vid_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:11:51,298 INFO sqlalchemy.engine.base.Engine (1629272847, '답십리지구대', '현장 종결', 11, 50, 12)
# 2021-08-18 18:11:51,299 INFO sqlalchemy.engine.base.Engine INSERT INTO report_list (time, police_name, status, loc_id, dc_id, vid_id) VALUES (?, ?, ?, ?, ?, ?)
# 2021-08-18 18:11:51,299 INFO sqlalchemy.engine.base.Engine (1629272831, '휘경파출소', '현장 종결', 11, 50, 13)
# 2021-08-18 18:11:51,300 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
session.rollback()
